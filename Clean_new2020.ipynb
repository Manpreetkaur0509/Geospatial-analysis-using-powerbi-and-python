# %%
import pandas as pd


import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Priyanka\Documents\Algonquin_College\Subjects\Data_Visulation\Project_Airbnb\AB_US_2020.csv")
df.tail(5)
# Out:
#               id                                               name  \
# 226025  45506143                          DC Hidden In Plain "Site"
# 226026  45511428  DC 3 BR w/ screen porch 3 blck to metro w/ par...
# 226027  45514685  Charming Penthouse Apt w/ Rooftop Terrace in L...
# 226028  45516412                Adams Morgan/Nat'l Zoo 1 BR Apt #32
# 226029  45517735    Beautiful large one-bedroom w/ washer and dryer
#
#           host_id host_name neighbourhood_group  \
# 226025   25973146     Marci                 NaN
# 226026  231133074    Thomas                 NaN
# 226027   33758935    Bassem                 NaN
# 226028   23193071   Michael                 NaN
# 226029   17789858      Adam                 NaN
#
#                                             neighbourhood   latitude  \
# 226025  Downtown, Chinatown, Penn Quarters, Mount Vern...  38.903880
# 226026                      Brookland, Brentwood, Langdon  38.920820
# ...

# %%
df.head()
# Out:
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (226030, 17)

# %%
missing_sum = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_info = pd.DataFrame({'Missing Values': missing_sum, 'Percentage Missing': missing_percentage})
missing_info.sort_values(by='Missing Values', ascending=False)
# Out:
#                                 Missing Values  Percentage Missing
# neighbourhood_group                     115845           51.252046
# reviews_per_month                        48602           21.502455
# last_review                              48602           21.502455
# host_name                                   33            0.014600
# name                                        28            0.012388
# id                                           0            0.000000
# minimum_nights                               0            0.000000
# availability_365                             0            0.000000
# calculated_host_listings_count               0            0.000000
# number_of_reviews                            0            0.000000
# room_type                                    0            0.000000
# price                                        0            0.000000
# longitude                                    0            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226030 entries, 0 to 226029
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              226030 non-null  int64
#  1   name                            226002 non-null  object
#  2   host_id                         226030 non-null  int64
#  3   host_name                       225997 non-null  object
#  4   neighbourhood_group             110185 non-null  object
#  5   neighbourhood                   226030 non-null  object
#  6   latitude                        226030 non-null  float64
#  7   longitude                       226030 non-null  float64
#  8   room_type                       226030 non-null  object
#  9   price                           226030 non-null  int64
#  10  minimum_nights                  226030 non-null  int64
#  11  number_of_reviews               226030 non-null  int64
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 226025    False
# 226026    False
# 226027    False
# 226028    False
# 226029    False
# Length: 226030, dtype: bool

# %%
df.nunique()
# Out:
# id                                226029
# name                              218443
# host_id                           130425
# host_name                          30533
# neighbourhood_group                   34
# neighbourhood                       1450
# latitude                          145091
# longitude                         145243
# room_type                              4
# price                               1975
# minimum_nights                       169
# number_of_reviews                    660
# last_review                         2377
# reviews_per_month                   1242
# calculated_host_listings_count       142
# availability_365                     366
# city                                  28
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                     0
# name                                  28
# host_id                                0
# host_name                             33
# neighbourhood_group               115845
# neighbourhood                          0
# latitude                               0
# longitude                              0
# room_type                              0
# price                                  0
# minimum_nights                         0
# number_of_reviews                      0
# last_review                        48602
# reviews_per_month                  48602
# calculated_host_listings_count         0
# availability_365                       0
# city                                   0
# dtype: int64

# %%
df['reviews_per_month'].fillna(0, inplace=True)

# %%
df.head(5)
# Out:
#        id                                               name  host_id  \
# 0   38585    Charming Victorian home - twin beds + breakfast   165529
# 1   80905                                   French Chic Loft   427027
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...   320564
# 3  155305                 Cottage! BonPaul + Sharky's Hostel   746673
# 4  160594                                Historic Grove Park   769252
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Evelyne                 NaN         28804  35.65146  -82.62792
# 1    Celeste                 NaN         28801  35.59779  -82.55540
# 2       Lisa                 NaN         28801  35.60670  -82.55563
# 3    BonPaul                 NaN         28806  35.57864  -82.59578
# 4  Elizabeth                 NaN         28801  35.61442  -82.54127
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df['last_review'] = df['last_review'].fillna(method='ffill')

# %%
df.boxplot('price', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('calculated_host_listings_count', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('minimum_nights', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('reviews_per_month', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('number_of_reviews', vert=False)
# Out:
# <Axes: >

# %%
# Removing Outliers
lower_bound = .25
upper_bound = .75
df = df[df['price'].between(df['price'].quantile(lower_bound), df['price'].quantile(upper_bound), inclusive=True)]
df = df[df['number_of_reviews'] > 0]
df = df[df['calculated_host_listings_count'] < 10]
df = df[df['number_of_reviews'] < 200]
df = df[df['minimum_nights'] < 10]
df = df[df['reviews_per_month'] < 5]

# %%
df.boxplot('price', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('calculated_host_listings_count', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('minimum_nights', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('reviews_per_month', vert=False)
# Out:
# <Axes: >

# %%
df.boxplot('number_of_reviews', vert=False)
# Out:
# <Axes: >

# %%
missing_sum = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_info = pd.DataFrame({'Missing Values': missing_sum, 'Percentage Missing': missing_percentage})
missing_info.sort_values(by='Missing Values', ascending=False)
# Out:
#                                 Missing Values  Percentage Missing
# neighbourhood_group                      29930           52.106546
# host_name                                    6            0.010446
# name                                         6            0.010446
# id                                           0            0.000000
# minimum_nights                               0            0.000000
# availability_365                             0            0.000000
# calculated_host_listings_count               0            0.000000
# reviews_per_month                            0            0.000000
# last_review                                  0            0.000000
# number_of_reviews                            0            0.000000
# room_type                                    0            0.000000
# price                                        0            0.000000
# longitude                                    0            0.000000
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  5.744000e+04  5.744000e+04  57440.000000  57440.000000  57440.000000
# mean   2.350967e+07  8.558933e+07     36.291368    -99.256249    125.050696
# std    1.248733e+07  9.219139e+07      6.663606     25.645191     37.128357
# min    3.440000e+02  2.300000e+01     18.982320   -159.711430     75.000000
# 25%    1.386264e+07  1.196788e+07     32.787785   -118.389465     95.000000
# 50%    2.340251e+07  4.656478e+07     37.804000    -90.092180    120.000000
# 75%    3.439332e+07  1.384263e+08     40.732955    -73.989050    150.000000
# max    4.549250e+07  3.679176e+08     47.734620    -70.995950    201.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    57440.000000       57440.000000       57440.000000
# mean         2.403325          39.306198           1.362309
# std          1.458450          45.317123           1.239642
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'city'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57440 entries, 5 to 226002
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              57440 non-null  int64
#  1   name                            57434 non-null  object
#  2   host_id                         57440 non-null  int64
#  3   host_name                       57434 non-null  object
#  4   neighbourhood_group             27510 non-null  object
#  5   neighbourhood                   57440 non-null  object
#  6   latitude                        57440 non-null  float64
#  7   longitude                       57440 non-null  float64
#  8   room_type                       57440 non-null  object
#  9   price                           57440 non-null  int64
#  10  minimum_nights                  57440 non-null  int64
#  11  number_of_reviews               57440 non-null  int64
# ...

# %%
# let's plot a pairplot
sns.pairplot(df[['minimum_nights', 'number_of_reviews',
       'reviews_per_month',
       'availability_365']])
plt.show()

# %%
# import linear regression model
from sklearn.linear_model import LinearRegression
# import module
from sklearn.model_selection import train_test_split
selected_features=[
       'minimum_nights', 'number_of_reviews',
       'reviews_per_month',
       'availability_365']
x = df[selected_features]
y= df['price']
# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1234)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((45952, 4), (45952,), (11488, 4), (11488,))

# %%
# train your model
lrmodel = LinearRegression().fit(x_train,y_train)

# make preditions on train set
train_pred = lrmodel.predict(x_train)

# %%
# evaluate your model
# we need mean absolute error
from sklearn.metrics import mean_absolute_error

train_mae = mean_absolute_error(train_pred, y_train)
print('Train error is', train_mae)
# Out:
# Train error is 31.341879975390267

# %%
# import decision tree model
from sklearn.tree import DecisionTreeRegressor

# %%
# create an instance of the class
dt = DecisionTreeRegressor(max_depth=3, max_features=10, random_state=567)

# %%
# train the model
dtmodel = dt.fit(x_train,y_train)

# %%
# make predictions using the test set
ytest_pred = dtmodel.predict(x_test)

# %%
# evaluate the model
test_mae = mean_absolute_error(ytest_pred, y_test)
test_mae
# Out:
# 31.06243209161851

# %%
# get the features
dtmodel.feature_names_in_
# Out:
# array(['minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'availability_365'], dtype=object)

# %%
# plot the tree
from sklearn import tree
import matplotlib.pyplot as plt
feature_names=['minimum_nights', 'number_of_reviews', 'reviews_per_month',
       'availability_365']
# Plot the tree with feature names
#tree.plot_tree(dtmodel, feature_names=dtmodel.feature_names_in_)
tree.plot_tree(dtmodel, feature_names=feature_names,filled=True,rounded=True)
tree.plot_tree(dtmodel)
plt.show()

# Save the plot to a file
plt.savefig('tree.png', dpi=300)

# %%
df.to_csv('AirBnb_2020_new.csv', index=None)
